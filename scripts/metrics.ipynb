# %%
import pandas as pd

# %%
metrics = pd.read_csv("/Data/iuliia.korotkova/FLIP/out/pipeline_runs/metrics_summary.csv")

# %%
metrics
# Out:
#             combo dataset model poisoner  budget  runs  poison_acc_mean  \
# 0  cifar_r32p_1xs   cifar  r32p      1xs     150     1            0.093
# 1  cifar_r32p_1xs   cifar  r32p      1xs     300     1            0.392
# 2  cifar_r32p_1xs   cifar  r32p      1xs     500     1            0.649
# 3  cifar_r32p_1xs   cifar  r32p      1xs    1000     1            0.991
# 4  cifar_r32p_1xs   cifar  r32p      1xs    1500     1            0.995
#
#    poison_acc_std  clean_acc_mean  clean_acc_std
# 0             0.0          0.9246            0.0
# 1             0.0          0.9252            0.0
# 2             0.0          0.9142            0.0
# 3             0.0          0.9066            0.0
# 4             0.0          0.8984            0.0
